# %%
# Recreate the following dataframe by using vectors and data.frame function
OL_Ratio <- c(76.2,82.1,78.9,74.3,77.7)
Leaf_Spot <-c(5.5,7.2,6.5,4.2,3.1)
Drought <-c('TRUE','FALSE','TRUE','FALSE','FALSE')
data<- data.frame(OL_Ratio,Leaf_Spot,Drought)

# %%
data
# Out:
#   OL_Ratio Leaf_Spot Drought
# 1 76.2     5.5       TRUE
# 2 82.1     7.2       FALSE
# 3 78.9     6.5       TRUE
# 4 74.3     4.2       FALSE
# 5 77.7     3.1       FALSE

# %%
# Which lines are considered drought tolerant?
subset(data, subset=Drought==TRUE)
# Out:
#   OL_Ratio Leaf_Spot Drought
# 1 76.2     5.5       TRUE
# 3 78.9     6.5       TRUE

# %%
#Input the peanut_lines (CSV) and peanut_disease (Tab) datafile
getwd()
# Out:
# [1] "/Users/tekan.rana"

# %%
setwd('/Users/tekan.rana/Desktop/Peanut data')
getwd()
# Out:
# [1] "/Users/tekan.rana/Desktop/Peanut data"

# %%
lines<-read.csv('peanut_lines.csv')
lines
# Out:
#     NC_Accession
# 1   ACI WT09-0761
# 2   ACI WT11-0351
# 3   ACI WT12-0226
# 4   ACI WT12-0419
# 5   ACI WT12-0420
# 6   ACI WT12-0433
# 7   Bailey
# 8   Bailey II
# 9   Brantley
# 10  CHAMPS
# 11  Emery
# 12  Florida Fancy
# 13  Florida-07
# 14  FloriGiant
# 15  FloRun 107
# 16  FloRun 157
# 17  FloRun 331
# 18  Georgia Green
# 19  Georgia-06G
# 20  Georgia-07W
# 21  Georgia-09B
# 22  Georgia-11J
# 23  Georgia-12Y
# 24  Gregory
# 25  Harris 1
# 26  HTS 02-06
# 27  HTS 15-04ol
# 28  N03088
# 29  N04067
# 30  N04072
# ... ...
# 830
# 831
# 832
# 833
# 834
# 835
# 836
# 837
# 838
# 839
# 840
# 841
# 842
# 843
# 844
# 845
# 846
# 847
# 848
# 849
# 850
# 851
# 852
# 853
# 854
# 855
# 856
# 857
# 858
# 859
#     Identity.or.Parentage
# 1   ACI WT09-0761
# 2   ACI WT11-0351
# 3   ACI WT12-0226
# 4   ACI WT12-0419
# 5   ACI WT12-0420
# 6   ACI WT12-0433
# 7   NC 12C*2 / N96076L
# 8   Bailey /4/ X07016, Bailey // X05027, Bailey / N02060ol, X05249 /3/ Bailey
# 9   Brantley
# 10  CHAMPS
# ...

# %%
disease <- read.delim('peanut_disease.txt', sep='\t')
disease
# Out:
#      Year Location Name  Label                                  NC_Accession
# 1    2010 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 2    2010 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 3    2011 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 4    2011 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 5    2012 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 6    2012 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 7    2013 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 8    2013 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 9    2014 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 10   2014 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 11   2015 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 12   2015 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# ...

# %%
#Check the column names of peanut_lines and peanut_disease
colnames(lines)
# Out:
# [1] "NC_Accession"          "Identity.or.Parentage" "Pedigree"
# [4] "FAG"

# %%
colnames(disease)
# Out:
# [1] "Year"         "Location"     "Name"         "Label"        "NC_Accession"
# [6] "Rating"       "Disease"

# %%
# Merge peanut_lines and peanut_disease keeping the entirety of the peanut_disease information intact - Name the data frame disease_data
disease_data <- merge(disease, lines)
disease_data
# Out:
#      NC_Accession Year Location Name  Label
# 1    Bailey       2010 LEW      ATP-T Advanced Testing Program - TSWV
# 2    Bailey       2016 RMT      ATP-S Advanced Testing Program - Sclerotinia
# 3    Bailey       2010 LEW      ATP-L Advanced Testing Program - Leafspot
# 4    Bailey       2016 RMT      ATP-S Advanced Testing Program - Sclerotinia
# 5    Bailey       2015 LEW      ATP-L Advanced Testing Program - Leafspot
# 6    Bailey       2014 LEW      ATP-L Advanced Testing Program - Leafspot
# 7    Bailey       2010 LEW      ATP-L Advanced Testing Program - Leafspot
# 8    Bailey       2017 LEW      ATP-L Advanced Testing Program - Leafspot
# 9    Bailey       2013 LEW      ATP-L Advanced Testing Program - Leafspot
# 10   Bailey       2010 LEW      ATP-L Advanced Testing Program - Leafspot
# 11   Bailey       2016 LEW      ATP-T Advanced Testing Program - TSWV
# 12   Bailey       2016 LEW      ATP-L Advanced Testing Program - Leafspot
# ...

# %%
# Subset the disease data to list only ratings for leaf spot ('LS') in a dataframe called leaf.spot
leaf.spot <-subset(disease_data, subset= Rating=='LS')
leaf.spot
# Out:
#      NC_Accession  Year Location Name  Label
# 10   Bailey        2010 LEW      ATP-L Advanced Testing Program - Leafspot
# 14   Bailey        2017 LEW      ATP-L Advanced Testing Program - Leafspot
# 20   Bailey        2016 LEW      ATP-L Advanced Testing Program - Leafspot
# 30   Bailey        2010 LEW      ATP-L Advanced Testing Program - Leafspot
# 33   Bailey        2016 LEW      ATP-L Advanced Testing Program - Leafspot
# 34   Bailey        2011 LEW      ATP-L Advanced Testing Program - Leafspot
# 38   Bailey        2015 LEW      ATP-L Advanced Testing Program - Leafspot
# 39   Bailey        2015 LEW      ATP-L Advanced Testing Program - Leafspot
# 42   Bailey        2014 LEW      ATP-L Advanced Testing Program - Leafspot
# 45   Bailey        2011 LEW      ATP-L Advanced Testing Program - Leafspot
# 48   Bailey        2013 LEW      ATP-L Advanced Testing Program - Leafspot
# 53   Bailey        2014 LEW      ATP-L Advanced Testing Program - Leafspot
# ...

# %%
Drop all rows that contain missing values in the column 'Disease'
leaf.spot[!is.na(leaf.spot$Disease),]
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:6: unexpected symbol
# 1: Drop all
#          ^
# Traceback:

# %%
# hat was the average leaf spot rating in 2017?
leaf.spot1 <- subset(leaf.spot, subset= Year== '2017')
leaf.spot1
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 8 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 8 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 8 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 8 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 8 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 8 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 8 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 8 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 8 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 8 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 8 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# ...

# %%
mean(leaf.spot$Disease)
# Out:
# [1] 5.082183

# %%
#Subset the leaf.spot dataframe to include only the following lines
#Hint: Look up %in% from the following reference - R Tutorials Operators
#line_names = 'Bailey', 'Bailey II', 'Wynne', 'Sullivan', 'Emery', 'N96076'
 v1 <- c('Bailey', 'Bailey II', 'Wynne', 'Sullivan', 'Emery', 'N96076')
v1
# Out:
# [1] "Bailey"    "Bailey II" "Wynne"     "Sullivan"  "Emery"     "N96076"

# %%
leaf.spot2<-leaf.spot1[(leaf.spot1$NC_Accession=='Bailey'| leaf.spot1$NC_Accession== 'Bailey II'|leaf.spot1$NC_Accession== 'Wynne'|leaf.spot1$NC_Accession== 'Sullivan'| leaf.spot1$NC_Accession=='Emery'|leaf.spot1$NC_Accession=='N96076'),]
leaf.spot2
# Out:
#      NC_Accession Year Location Name  Label
# 14   Bailey       2017 LEW      ATP-L Advanced Testing Program - Leafspot
# 73   Bailey II    2017 LEW      ATP-L Advanced Testing Program - Leafspot
# 151  Emery        2017 LEW      ATP-L Advanced Testing Program - Leafspot
# 156  Emery        2017 LEW      ATP-L Advanced Testing Program - Leafspot
# 2603 Sullivan     2017 LEW      ATP-L Advanced Testing Program - Leafspot
# 2616 Sullivan     2017 LEW      ATP-L Advanced Testing Program - Leafspot
# 2672 Wynne        2017 LEW      ATP-L Advanced Testing Program - Leafspot
# 2673 Wynne        2017 LEW      ATP-L Advanced Testing Program - Leafspot
#      Rating Disease
# 14   LS     8.00
# 73   LS     7.77
# 151  LS     8.00
# 156  LS     8.11
# 2603 LS     8.00
# 2616 LS     7.38
# 2672 LS     7.80
# 2673 LS     8.00
#      Identity.or.Parentage
# 14   NC 12C*2 / N96076L
# 73   Bailey /4/ X07016, Bailey // X05027, Bailey / N02060ol, X05249 /3/ Bailey
# 151  N03079FT*2 / Brantley
# ...

# %%
Which line is the most leaf spot resistant?
max(leaf.spot2$Disease)
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:7: unexpected symbol
# 1: Which line
#           ^
# Traceback:

# %%
help(aggregate)

# %%
Load the libarary XLSX and output the aggregated dataframe as Leaf Spot.xlsx
install.packages('xlsx',repos="http://cran.rstudio.com/")
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:6: unexpected symbol
# 1: Load the
#          ^
# Traceback:
